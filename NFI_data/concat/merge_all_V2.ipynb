# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# ddl datasets
data_parc = pd.read_excel('IFN/data_parcelles_with_gps.xlsx')
data_trees = pd.read_excel('IFN/data_trees.xlsx')
data_m_accr = pd.read_excel('IFN/data_m_accr_with_gps.xlsx')

# %%
# removing useless columns
data_parc.drop(['Unnamed: 0','INVNR'],axis=1, inplace=True)
data_trees.drop(['Unnamed: 0','INVNR'],axis=1, inplace=True)
data_m_accr.drop('Unnamed: 0',axis=1, inplace=True)

# %%
# adding LFI id
data_m_accr['LFI'] = data_m_accr['LFI'].apply(lambda s : s.split('-')[1])

# %%
data_parc.head()
# Out:
#    PARCELLE        LAT       LON         ALT  PRODREG  HT_VEG       DATE  \
# 0        51  47.781623  8.612822  715.918970        1       3 1984-04-10
# 1        51  47.781623  8.612822  715.918970        1       3 1994-10-19
# 2        51  47.781623  8.612822  715.918970        1       3 2011-11-09
# 3        51  47.781623  8.612822  715.918970        1       3 2005-11-01
# 4       384  47.736528  8.625154  563.829759        1       2 1995-07-10
#
#      SLOPE25    ASPECT25  PERF_CROI  ...  V_LARCH  V_ARVEN  V_UENDH  \
# 0  58.407726   67.342415       4676  ...      0.0      0.0      0.0
# 1  58.407726   67.342415       4676  ...      0.0      0.0      0.0
# 2  58.407726   67.342415       4676  ...      0.0      0.0      0.0
# 3  58.407726   67.342415       4676  ...      0.0      0.0      0.0
# 4  55.683254  253.354935       3402  ...      0.0      0.0      0.0
#
#       V_BUCHE  V_AHORN  V_ESCHE  V_EICHE  V_CASTA   V_UELBH   LFI
# ...

# %% [markdown]
# - conversion spatial coordinates in international referential

# %%
c = 0
for parc in data_parc['PARCELLE'].unique():
    if data_parc.loc[data_parc['PARCELLE']==parc,'LAT'].std() != 0 or data_parc.loc[data_parc['PARCELLE']==parc,'LON'].std() != 0:
        c+=1
print(c)
# Out:
# 0

# %%
c = 0
for parc in data_m_accr['PARCELLE'].unique():
    if data_m_accr.loc[data_m_accr['PARCELLE']==parc,'LAT'].std() > 0.0001 or data_m_accr.loc[data_m_accr['PARCELLE']==parc,'LON'].std() > 0.0001:
        c+=1
print(c)
# Out:
# 0

# %%
c = 0
for parc in data_m_accr['PARCELLE'].unique():
    for lfi in data_m_accr['LFI'].unique():
        to_keep_1 = (data_m_accr['PARCELLE']==parc) & (data_m_accr['LFI']==lfi)
        to_keep_2 = (data_parc['PARCELLE']==parc) & (data_parc['LFI']==lfi)
        diff_lat = abs(float(data_m_accr.loc[to_keep_1,:]['LAT']) - float(data_parc.loc[to_keep_2,:]['LAT']))
        diff_lon = abs(float(data_m_accr.loc[to_keep_1,:]['LON']) - float(data_parc.loc[to_keep_2,:]['LON']))
    if diff_lat >= 0.0001 or diff_lon >= 0.0001:
         c+=1
print(c)
# Out:
# 0

# %% [markdown]
# - merge plot, mortality and increment datasets

# %%
data_parc_m_accr = data_parc.merge(data_m_accr, how='outer', on=['PARCELLE','LFI'])

# %%
data_parc_m_accr.rename(columns={'LAT_x':'LAT','LON_x':'LON'}, inplace=True)

# %%
data_parc_m_accr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9612 entries, 0 to 9611
# Data columns (total 99 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   PARCELLE                    9612 non-null   int64
#  1   LAT                         9612 non-null   float64
#  2   LON                         9612 non-null   float64
#  3   ALT                         9612 non-null   float64
#  4   PRODREG                     9612 non-null   int64
#  5   HT_VEG                      9612 non-null   int64
#  6   DATE                        9612 non-null   datetime64[ns]
#  7   SLOPE25                     9612 non-null   float64
#  8   ASPECT25                    9612 non-null   float64
#  9   PERF_CROI                   9612 non-null   int64
#  10  QUAL_STATION                9612 non-null   int64
#  11  UNIT_VEG_FINE               9612 non-null   int64
#  12  UNIT_VEG_GROS               9612 non-null   int64
# ...

# %%
data_parc_m_accr.drop(['LAT_y','LON_y'], axis=1, inplace=True)

# %% [markdown]
# - tree dataset

# %%
# calculation of median
var_to_med = ["PARCELLE", "LFI", "DBH", "HAUTEUR_ARBRE", "AGE_ARBRE"]
tree_med = data_trees[var_to_med].groupby(['PARCELLE','LFI']).median().reset_index()
tree_med.head()
# Out:
#    PARCELLE   LFI   DBH  HAUTEUR_ARBRE  AGE_ARBRE
# 0        51  LFI1  23.0          16.00        NaN
# 1        51  LFI2  26.0          25.00        NaN
# 2        51  LFI3  29.0          29.00        NaN
# 3        51  LFI4  30.5          30.55       80.0
# 4       384  LFI1  44.0          28.50        NaN

# %%
# calculation of the most represented category
for c in ["ETAGE", "ENDOMMAGEMENT", "NB_DEGAT_ARBRE"]:
    tree_med[c] = data_trees[c].value_counts().reset_index().iloc[0,0]

# %%
tree_med.head()
# Out:
#    PARCELLE   LFI   DBH  HAUTEUR_ARBRE  AGE_ARBRE  ETAGE  ENDOMMAGEMENT  \
# 0        51  LFI1  23.0          16.00        NaN    1.0            1.0
# 1        51  LFI2  26.0          25.00        NaN    1.0            1.0
# 2        51  LFI3  29.0          29.00        NaN    1.0            1.0
# 3        51  LFI4  30.5          30.55       80.0    1.0            1.0
# 4       384  LFI1  44.0          28.50        NaN    1.0            1.0
#
#    NB_DEGAT_ARBRE
# 0             1.0
# 1             1.0
# 2             1.0
# 3             1.0
# 4             1.0

# %% [markdown]
# - final merge

# %%
big_data = data_parc_m_accr.merge(tree_med, on=['PARCELLE','LFI'], how='outer')

# %%
display(big_data)
print(big_data.shape)
# Out:
#       PARCELLE        LAT       LON         ALT  PRODREG  HT_VEG       DATE  \
# 0           51  47.781623  8.612822  715.918970        1       3 1984-04-10
# 1           51  47.781623  8.612822  715.918970        1       3 1994-10-19
# 2           51  47.781623  8.612822  715.918970        1       3 2011-11-09
# 3           51  47.781623  8.612822  715.918970        1       3 2005-11-01
# 4          384  47.736528  8.625154  563.829759        1       2 1995-07-10
# ...        ...        ...       ...         ...      ...     ...        ...
# 9607    165003  45.869258  9.035470  668.776978        5       2 1985-03-18
# 9608    165065  45.860080  9.048080  996.563990        5       3 1995-05-09
# 9609    165065  45.860080  9.048080  996.563990        5       3 1985-03-14
# 9610    165065  45.860080  9.048080  996.563990        5       3 2006-04-13
# 9611    165065  45.860080  9.048080  996.563990        5       3 2013-10-09
#
# ...

# %% [markdown]
# - saving

# %%
big_data.to_excel('IFN/data_big_merge_base.xlsx')

# %% [markdown]
# - heatmap

# %%
plt.figure(figsize = (40,40))
data_corr = big_data.corr()
sns.heatmap(abs(data_corr))
# Out:
# <AxesSubplot:>

# %% [markdown]
# appending meteorological data

# %%
meteo2 = pd.read_excel('meteo_data/full_meteo_file.xlsx',sheet_name='LFI1-2')
meteo3 = pd.read_excel('meteo_data/full_meteo_file.xlsx',sheet_name='LFI2-3')
meteo4 = pd.read_excel('meteo_data/full_meteo_file.xlsx',sheet_name='LFI3-4')

# %%
new1 = big_data[big_data['LFI'] == 'LFI1']
new2 = pd.merge(big_data[big_data['LFI'] == 'LFI2'],meteo2,left_on='PARCELLE',right_on='CLNR')
new3 = pd.merge(big_data[big_data['LFI'] == 'LFI3'],meteo3,left_on='PARCELLE',right_on='CLNR')
new4 = pd.merge(big_data[big_data['LFI'] == 'LFI4'],meteo4,left_on='PARCELLE',right_on='CLNR')

# %%
new_full = new1.append(new2, ignore_index=True)
new_full = new_full.append(new3, ignore_index=True)
new_full = new_full.append(new4, ignore_index=True)

# %%
new_full = new_full.sort_values(by='PARCELLE')
new_full.to_excel('NFI_data/modified files/big_merge_V2_meteo.xlsx')

# %% [markdown]
# appending satellite data

# %%
sat1 = pd.read_excel('sat_data/Data_from_satellites_images_LFI1.xlsx')
sat2 = pd.read_excel('sat_data/Data_from_satellites_images_LFI2.xlsx')
sat3 = pd.read_excel('sat_data/Data_from_satellites_images_LFI3.xlsx')
sat4 = pd.read_excel('sat_data/Data_from_satellites_images_LFI4.xlsx')
sat1.drop('Unnamed: 0',axis=1,inplace=True)
sat2.drop('Unnamed: 0',axis=1,inplace=True)
sat3.drop('Unnamed: 0',axis=1,inplace=True)
sat4.drop('Unnamed: 0',axis=1,inplace=True)

# %%
new1 = pd.merge(big_data[big_data['LFI'] == 'LFI1'],sat1,left_on='PARCELLE',right_on='PARCELLE')
new2 = pd.merge(big_data[big_data['LFI'] == 'LFI2'],sat2,left_on='PARCELLE',right_on='PARCELLE')
new3 = pd.merge(big_data[big_data['LFI'] == 'LFI3'],sat3,left_on='PARCELLE',right_on='PARCELLE')
new4 = pd.merge(big_data[big_data['LFI'] == 'LFI4'],sat4,left_on='PARCELLE',right_on='PARCELLE')

# %%
new_full = new1.append(new2, ignore_index=True)
new_full = new_full.append(new3, ignore_index=True)
new_full = new_full.append(new4, ignore_index=True)

# %%
new_full = new_full.sort_values(by='PARCELLE')
new_full.to_excel('NFI_data/modified files/big_merge_meteo_sat.xlsx')
